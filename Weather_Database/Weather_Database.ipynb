# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\hansf\anaconda3\envs\pythondata\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: kdtree>=0.12 in c:\users\hansf\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
         # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | ust-nera
# Processing Record 5 of Set 1 | ancud
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | constitucion
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | tacuarembo
# Processing Record 15 of Set 1 | mount gambier
# Processing Record 16 of Set 1 | boyolangu
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | hoquiam
# Processing Record 20 of Set 1 | cururupu
# Processing Record 21 of Set 1 | beloha
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | araouane
# Processing Record 24 of Set 1 | san luis
# Processing Record 25 of Set 1 | sampit
# Processing Record 26 of Set 1 | narsaq
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | karasburg
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | bourges
# Processing Record 31 of Set 1 | pecos
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | mullingar
# Processing Record 37 of Set 1 | urucara
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | nome
# Processing Record 46 of Set 1 | san carlos de bariloche
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | maceio
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | pacific grove
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | ukiah
# Processing Record 10 of Set 2 | katherine
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | cap malheureux
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | moree
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | storslett
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | boguchany
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | manama
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | palembang
# Processing Record 27 of Set 2 | chapada dos guimaraes
# Processing Record 28 of Set 2 | turukhansk
# Processing Record 29 of Set 2 | kadyy
# Processing Record 30 of Set 2 | nouadhibou
# Processing Record 31 of Set 2 | olavarria
# Processing Record 32 of Set 2 | coruripe
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | necochea
# Processing Record 35 of Set 2 | oksfjord
# Processing Record 36 of Set 2 | baglung
# Processing Record 37 of Set 2 | hambantota
# Processing Record 38 of Set 2 | westport
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | oskarshamn
# Processing Record 41 of Set 2 | sangar
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | camacha
# Processing Record 47 of Set 2 | xifeng
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | chengde
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | kavaratti
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | kirkland lake
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | cozumel
# Processing Record 7 of Set 3 | abnub
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | magistralnyy
# Processing Record 10 of Set 3 | algiers
# Processing Record 11 of Set 3 | wollongong
# Processing Record 12 of Set 3 | gornopravdinsk
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | mandurah
# Processing Record 15 of Set 3 | homer
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | senno
# Processing Record 19 of Set 3 | leningradskiy
# Processing Record 20 of Set 3 | tefe
# Processing Record 21 of Set 3 | moron
# Processing Record 22 of Set 3 | salalah
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | pochutla
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | sabang
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | nelson bay
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | la ronge
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | ahvaz
# Processing Record 39 of Set 3 | puerto escondido
# Processing Record 40 of Set 3 | diplo
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | kleck
# City not found. Skipping...
# Processing Record 43 of Set 3 | calatayud
# Processing Record 44 of Set 3 | hun
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | solnechnyy
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | airai
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | vadso
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | egvekinot
# Processing Record 3 of Set 4 | cidreira
# Processing Record 4 of Set 4 | montorio al vomano
# Processing Record 5 of Set 4 | karratha
# Processing Record 6 of Set 4 | cherskiy
# Processing Record 7 of Set 4 | lichinga
# Processing Record 8 of Set 4 | adrar
# Processing Record 9 of Set 4 | lardos
# Processing Record 10 of Set 4 | bundaberg
# Processing Record 11 of Set 4 | xiongzhou
# Processing Record 12 of Set 4 | buala
# Processing Record 13 of Set 4 | kudahuvadhoo
# Processing Record 14 of Set 4 | college
# Processing Record 15 of Set 4 | liberal
# Processing Record 16 of Set 4 | coxim
# Processing Record 17 of Set 4 | sibolga
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | antofagasta
# Processing Record 20 of Set 4 | bonthe
# Processing Record 21 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 4 | tanete
# Processing Record 23 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 4 | atambua
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 4 | newport
# Processing Record 29 of Set 4 | new ulm
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | zhangye
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | meulaboh
# Processing Record 34 of Set 4 | changli
# Processing Record 35 of Set 4 | dakar
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | nabire
# Processing Record 38 of Set 4 | monrovia
# Processing Record 39 of Set 4 | belyy gorodok
# Processing Record 40 of Set 4 | tasiilaq
# Processing Record 41 of Set 4 | san quintin
# Processing Record 42 of Set 4 | sovetskiy
# Processing Record 43 of Set 4 | carballo
# Processing Record 44 of Set 4 | honiara
# Processing Record 45 of Set 4 | san patricio
# Processing Record 46 of Set 4 | mahebourg
# Processing Record 47 of Set 4 | gushikawa
# Processing Record 48 of Set 4 | ahipara
# Processing Record 49 of Set 4 | brae
# Processing Record 50 of Set 4 | novochernorechenskiy
# Processing Record 1 of Set 5 | santa maria
# Processing Record 2 of Set 5 | north bend
# Processing Record 3 of Set 5 | ongandjera
# Processing Record 4 of Set 5 | kerman
# Processing Record 5 of Set 5 | comodoro rivadavia
# Processing Record 6 of Set 5 | andenes
# Processing Record 7 of Set 5 | asau
# Processing Record 8 of Set 5 | carutapera
# Processing Record 9 of Set 5 | impfondo
# Processing Record 10 of Set 5 | matou
# Processing Record 11 of Set 5 | moravske budejovice
# Processing Record 12 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 13 of Set 5 | chabahar
# Processing Record 14 of Set 5 | manggar
# Processing Record 15 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 5 | weyburn
# Processing Record 17 of Set 5 | clyde river
# Processing Record 18 of Set 5 | niort
# Processing Record 19 of Set 5 | las palmas
# Processing Record 20 of Set 5 | la asuncion
# Processing Record 21 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 22 of Set 5 | le port
# Processing Record 23 of Set 5 | ugoofaaru
# Processing Record 24 of Set 5 | rio claro
# Processing Record 25 of Set 5 | mount pleasant
# Processing Record 26 of Set 5 | neenah
# Processing Record 27 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 5 | hovd
# Processing Record 29 of Set 5 | sept-iles
# Processing Record 30 of Set 5 | balud
# Processing Record 31 of Set 5 | kushmurun
# Processing Record 32 of Set 5 | amapa
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | henties bay
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | olafsvik
# Processing Record 37 of Set 5 | tilichiki
# Processing Record 38 of Set 5 | sabha
# Processing Record 39 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 40 of Set 5 | saint-francois
# Processing Record 41 of Set 5 | zmievka
# City not found. Skipping...
# Processing Record 42 of Set 5 | sweetwater
# Processing Record 43 of Set 5 | alberdi
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 46 of Set 5 | coahuayana
# Processing Record 47 of Set 5 | upata
# Processing Record 48 of Set 5 | khorramshahr
# Processing Record 49 of Set 5 | khani
# Processing Record 50 of Set 5 | flinders
# Processing Record 1 of Set 6 | vanimo
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | demyansk
# Processing Record 4 of Set 6 | oriximina
# Processing Record 5 of Set 6 | poum
# Processing Record 6 of Set 6 | aguascalientes
# Processing Record 7 of Set 6 | tosya
# Processing Record 8 of Set 6 | excelsior springs
# Processing Record 9 of Set 6 | bilisht
# Processing Record 10 of Set 6 | goure
# Processing Record 11 of Set 6 | magdalena
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | itaituba
# Processing Record 14 of Set 6 | kargopol
# Processing Record 15 of Set 6 | nyrob
# Processing Record 16 of Set 6 | chebsara
# Processing Record 17 of Set 6 | nemuro
# Processing Record 18 of Set 6 | fairbanks
# Processing Record 19 of Set 6 | hithadhoo
# Processing Record 20 of Set 6 | gusinoye ozero
# Processing Record 21 of Set 6 | jalu
# Processing Record 22 of Set 6 | alofi
# Processing Record 23 of Set 6 | makakilo city
# Processing Record 24 of Set 6 | dinar
# Processing Record 25 of Set 6 | praia
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | vestmanna
# Processing Record 28 of Set 6 | atar
# Processing Record 29 of Set 6 | katol
# Processing Record 30 of Set 6 | dunedin
# Processing Record 31 of Set 6 | bambous virieux
# Processing Record 32 of Set 6 | talnakh
# Processing Record 33 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 6 | sechura
# Processing Record 35 of Set 6 | pedernales
# Processing Record 36 of Set 6 | ribeira grande
# Processing Record 37 of Set 6 | obarsia-closani
# City not found. Skipping...
# Processing Record 38 of Set 6 | port-gentil
# Processing Record 39 of Set 6 | auki
# Processing Record 40 of Set 6 | srandakan
# Processing Record 41 of Set 6 | gampengrejo
# Processing Record 42 of Set 6 | kerema
# Processing Record 43 of Set 6 | yerofey pavlovich
# Processing Record 44 of Set 6 | mount barker
# Processing Record 45 of Set 6 | viedma
# Processing Record 46 of Set 6 | pando
# Processing Record 47 of Set 6 | grindavik
# Processing Record 48 of Set 6 | hoshcha
# Processing Record 49 of Set 6 | lasa
# Processing Record 50 of Set 6 | plettenberg bay
# Processing Record 1 of Set 7 | taltal
# Processing Record 2 of Set 7 | ostrovnoy
# Processing Record 3 of Set 7 | deputatskiy
# Processing Record 4 of Set 7 | san rafael
# Processing Record 5 of Set 7 | vieux-habitants
# Processing Record 6 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 7 | biltine
# Processing Record 8 of Set 7 | asfi
# Processing Record 9 of Set 7 | russell
# Processing Record 10 of Set 7 | kaseda
# Processing Record 11 of Set 7 | casper
# Processing Record 12 of Set 7 | rio grande
# Processing Record 13 of Set 7 | belyy yar
# Processing Record 14 of Set 7 | olenegorsk
# Processing Record 15 of Set 7 | elizabeth city
# Processing Record 16 of Set 7 | ponta do sol
# Processing Record 17 of Set 7 | san juan bautista
# Processing Record 18 of Set 7 | diego de almagro
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | yar-sale
# Processing Record 21 of Set 7 | santarem
# Processing Record 22 of Set 7 | xuddur
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | horki
# Processing Record 25 of Set 7 | barranca
# Processing Record 26 of Set 7 | praia da vitoria
# Processing Record 27 of Set 7 | aleksandrov gay
# Processing Record 28 of Set 7 | tromso
# Processing Record 29 of Set 7 | osmena
# Processing Record 30 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 31 of Set 7 | silopi
# Processing Record 32 of Set 7 | timbo
# Processing Record 33 of Set 7 | namibe
# Processing Record 34 of Set 7 | waddan
# Processing Record 35 of Set 7 | saint anthony
# Processing Record 36 of Set 7 | puri
# Processing Record 37 of Set 7 | mount isa
# Processing Record 38 of Set 7 | tura
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | bukachacha
# Processing Record 41 of Set 7 | panjab
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | jishou
# Processing Record 44 of Set 7 | bandar-e lengeh
# Processing Record 45 of Set 7 | aitape
# Processing Record 46 of Set 7 | lexington
# Processing Record 47 of Set 7 | bilibino
# Processing Record 48 of Set 7 | havre-saint-pierre
# Processing Record 49 of Set 7 | pahrump
# Processing Record 50 of Set 7 | tacoronte
# Processing Record 1 of Set 8 | chimbote
# Processing Record 2 of Set 8 | mao
# Processing Record 3 of Set 8 | mahon
# Processing Record 4 of Set 8 | bethel
# Processing Record 5 of Set 8 | general roca
# Processing Record 6 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 7 of Set 8 | saint-augustin
# Processing Record 8 of Set 8 | sukhoverkovo
# City not found. Skipping...
# Processing Record 9 of Set 8 | port hardy
# Processing Record 10 of Set 8 | port hedland
# Processing Record 11 of Set 8 | samarai
# Processing Record 12 of Set 8 | najran
# Processing Record 13 of Set 8 | borama
# City not found. Skipping...
# Processing Record 14 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 8 | barra
# Processing Record 16 of Set 8 | santa rosa
# Processing Record 17 of Set 8 | gubkinskiy
# Processing Record 18 of Set 8 | shelburne
# Processing Record 19 of Set 8 | guacari
# Processing Record 20 of Set 8 | havoysund
# Processing Record 21 of Set 8 | tawang
# Processing Record 22 of Set 8 | maniwaki
# Processing Record 23 of Set 8 | hailar
# Processing Record 24 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | lorengau
# Processing Record 28 of Set 8 | japura
# Processing Record 29 of Set 8 | emmett
# Processing Record 30 of Set 8 | lundazi
# Processing Record 31 of Set 8 | swindon
# Processing Record 32 of Set 8 | marsh harbour
# Processing Record 33 of Set 8 | agadir
# Processing Record 34 of Set 8 | berdigestyakh
# Processing Record 35 of Set 8 | drobak
# Processing Record 36 of Set 8 | lucapa
# Processing Record 37 of Set 8 | broken hill
# Processing Record 38 of Set 8 | anadyr
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | iqaluit
# Processing Record 41 of Set 8 | lagoa
# Processing Record 42 of Set 8 | zhuhai
# Processing Record 43 of Set 8 | cayenne
# Processing Record 44 of Set 8 | vestmannaeyjar
# Processing Record 45 of Set 8 | karpathos
# Processing Record 46 of Set 8 | kisaran
# Processing Record 47 of Set 8 | chapais
# Processing Record 48 of Set 8 | nikolayevsk-na-amure
# Processing Record 49 of Set 8 | teguldet
# Processing Record 50 of Set 8 | bagn
# Processing Record 1 of Set 9 | urla
# Processing Record 2 of Set 9 | hobyo
# Processing Record 3 of Set 9 | upernavik
# Processing Record 4 of Set 9 | dwarka
# Processing Record 5 of Set 9 | berezovyy
# Processing Record 6 of Set 9 | marshalltown
# Processing Record 7 of Set 9 | olkhovka
# Processing Record 8 of Set 9 | shintomi
# Processing Record 9 of Set 9 | labuan
# Processing Record 10 of Set 9 | zamosc
# Processing Record 11 of Set 9 | flin flon
# Processing Record 12 of Set 9 | acajutla
# Processing Record 13 of Set 9 | hidalgo
# Processing Record 14 of Set 9 | half moon bay
# Processing Record 15 of Set 9 | ankang
# Processing Record 16 of Set 9 | bowen
# Processing Record 17 of Set 9 | majene
# Processing Record 18 of Set 9 | lavrentiya
# Processing Record 19 of Set 9 | bobo dioulasso
# Processing Record 20 of Set 9 | tongliao
# Processing Record 21 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 9 | vila
# Processing Record 23 of Set 9 | rawson
# Processing Record 24 of Set 9 | pudozh
# Processing Record 25 of Set 9 | kimbe
# Processing Record 26 of Set 9 | roma
# Processing Record 27 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 9 | pontal do parana
# Processing Record 29 of Set 9 | katsuura
# Processing Record 30 of Set 9 | oranjestad
# Processing Record 31 of Set 9 | lagunas
# Processing Record 32 of Set 9 | tomatlan
# Processing Record 33 of Set 9 | redlands
# Processing Record 34 of Set 9 | qasigiannguit
# Processing Record 35 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 9 | tecoanapa
# Processing Record 37 of Set 9 | green river
# Processing Record 38 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 39 of Set 9 | tessalit
# Processing Record 40 of Set 9 | marzuq
# Processing Record 41 of Set 9 | sorland
# Processing Record 42 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 9 | dauriya
# Processing Record 44 of Set 9 | ambilobe
# Processing Record 45 of Set 9 | pyapon
# Processing Record 46 of Set 9 | kushiro
# Processing Record 47 of Set 9 | savannah bight
# Processing Record 48 of Set 9 | fuengirola
# Processing Record 49 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 9 | myitkyina
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 2 of Set 10 | brooks
# Processing Record 3 of Set 10 | lubbock
# Processing Record 4 of Set 10 | damietta
# Processing Record 5 of Set 10 | bose
# Processing Record 6 of Set 10 | vangazi
# Processing Record 7 of Set 10 | laguna
# Processing Record 8 of Set 10 | sambava
# Processing Record 9 of Set 10 | natal
# Processing Record 10 of Set 10 | londonderry
# Processing Record 11 of Set 10 | jhargram
# Processing Record 12 of Set 10 | pueblo
# Processing Record 13 of Set 10 | parkes
# Processing Record 14 of Set 10 | dryden
# Processing Record 15 of Set 10 | naryan-mar
# Processing Record 16 of Set 10 | bandarbeyla
# Processing Record 17 of Set 10 | port shepstone
# Processing Record 18 of Set 10 | lulea
# Processing Record 19 of Set 10 | taoudenni
# Processing Record 20 of Set 10 | matara
# Processing Record 21 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 22 of Set 10 | boa vista
# Processing Record 23 of Set 10 | mareeba
# Processing Record 24 of Set 10 | mexico
# Processing Record 25 of Set 10 | dukat
# Processing Record 26 of Set 10 | sembe
# Processing Record 27 of Set 10 | kurumkan
# Processing Record 28 of Set 10 | natchitoches
# Processing Record 29 of Set 10 | sao gabriel da cachoeira
# Processing Record 30 of Set 10 | dingle
# Processing Record 31 of Set 10 | evensk
# Processing Record 32 of Set 10 | namatanai
# Processing Record 33 of Set 10 | roald
# Processing Record 34 of Set 10 | korla
# Processing Record 35 of Set 10 | baramati
# Processing Record 36 of Set 10 | kindu
# Processing Record 37 of Set 10 | morondava
# Processing Record 38 of Set 10 | walvis bay
# Processing Record 39 of Set 10 | watertown
# Processing Record 40 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 10 | port blair
# Processing Record 42 of Set 10 | hualmay
# Processing Record 43 of Set 10 | bayshore gardens
# Processing Record 44 of Set 10 | san bartolome de tirajana
# Processing Record 45 of Set 10 | shibarghan
# City not found. Skipping...
# Processing Record 46 of Set 10 | igarka
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | golden
# Processing Record 49 of Set 10 | talaya
# Processing Record 50 of Set 10 | sarangani
# Processing Record 1 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | taipu
# Processing Record 3 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 4 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 11 | imeni babushkina
# Processing Record 6 of Set 11 | orodara
# Processing Record 7 of Set 11 | belmonte
# Processing Record 8 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 9 of Set 11 | awjilah
# Processing Record 10 of Set 11 | changtu
# Processing Record 11 of Set 11 | chumikan
# Processing Record 12 of Set 11 | lenger
# Processing Record 13 of Set 11 | athabasca
# Processing Record 14 of Set 11 | vostok
# Processing Record 15 of Set 11 | komsomolskiy
# Processing Record 16 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 11 | biak
# Processing Record 18 of Set 11 | arlit
# Processing Record 19 of Set 11 | gwanda
# Processing Record 20 of Set 11 | george town
# Processing Record 21 of Set 11 | lompoc
# Processing Record 22 of Set 11 | sabancuy
# Processing Record 23 of Set 11 | joensuu
# Processing Record 24 of Set 11 | quang ngai
# Processing Record 25 of Set 11 | faya
# Processing Record 26 of Set 11 | devgarh
# Processing Record 27 of Set 11 | sola
# Processing Record 28 of Set 11 | carbonia
# Processing Record 29 of Set 11 | sinnamary
# Processing Record 30 of Set 11 | uyemskiy
# Processing Record 31 of Set 11 | moranbah
# Processing Record 32 of Set 11 | luwuk
# Processing Record 33 of Set 11 | kikwit
# Processing Record 34 of Set 11 | yemelyanovo
# Processing Record 35 of Set 11 | valley city
# Processing Record 36 of Set 11 | bariadi
# Processing Record 37 of Set 11 | fukue
# Processing Record 38 of Set 11 | never
# Processing Record 39 of Set 11 | kongsberg
# Processing Record 40 of Set 11 | benghazi
# Processing Record 41 of Set 11 | hit
# Processing Record 42 of Set 11 | myre
# Processing Record 43 of Set 11 | fonte boa
# Processing Record 44 of Set 11 | alihe
# Processing Record 45 of Set 11 | margate
# Processing Record 46 of Set 11 | caravelas
# Processing Record 47 of Set 11 | balkhash
# Processing Record 48 of Set 11 | kaeo
# Processing Record 49 of Set 11 | gat
# Processing Record 50 of Set 11 | kushima
# Processing Record 1 of Set 12 | hamilton
# Processing Record 2 of Set 12 | tiznit
# Processing Record 3 of Set 12 | gryfino
# Processing Record 4 of Set 12 | kondopoga
# Processing Record 5 of Set 12 | alghero
# Processing Record 6 of Set 12 | oktyabrskoye
# Processing Record 7 of Set 12 | timra
# Processing Record 8 of Set 12 | chiang klang
# Processing Record 9 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 12 | los llanos de aridane
# Processing Record 11 of Set 12 | baltay
# Processing Record 12 of Set 12 | rey bouba
# Processing Record 13 of Set 12 | te anau
# Processing Record 14 of Set 12 | okakarara
# Processing Record 15 of Set 12 | beringovskiy
# Processing Record 16 of Set 12 | havelock
# Processing Record 17 of Set 12 | kodinsk
# Processing Record 18 of Set 12 | vermilion
# Processing Record 19 of Set 12 | si sa ket
# Processing Record 20 of Set 12 | kloulklubed
# Processing Record 21 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 22 of Set 12 | carauari
# Processing Record 23 of Set 12 | tiarei
# Processing Record 24 of Set 12 | umm kaddadah
# Processing Record 25 of Set 12 | bulz
# Processing Record 26 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 12 | myingyan
# Processing Record 28 of Set 12 | herat
# Processing Record 29 of Set 12 | alice springs
# Processing Record 30 of Set 12 | prince rupert
# Processing Record 31 of Set 12 | tamandare
# Processing Record 32 of Set 12 | muswellbrook
# Processing Record 33 of Set 12 | maragogi
# Processing Record 34 of Set 12 | aswan
# Processing Record 35 of Set 12 | ponta delgada
# Processing Record 36 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 12 | fredericksburg
# Processing Record 38 of Set 12 | limbang
# Processing Record 39 of Set 12 | ambon
# Processing Record 40 of Set 12 | noumea
# Processing Record 41 of Set 12 | anjozorobe
# Processing Record 42 of Set 12 | katobu
# Processing Record 43 of Set 12 | sao joao da barra
# Processing Record 44 of Set 12 | liniere
# City not found. Skipping...
# Processing Record 45 of Set 12 | pontes e lacerda
# Processing Record 46 of Set 12 | thai binh
# Processing Record 47 of Set 12 | miracema do tocantins
# Processing Record 48 of Set 12 | buluang
# Processing Record 49 of Set 12 | starodub
# Processing Record 50 of Set 12 | khandyga
# Processing Record 1 of Set 13 | mogocha
# Processing Record 2 of Set 13 | san juan
# Processing Record 3 of Set 13 | raahe
# Processing Record 4 of Set 13 | grand-santi
# Processing Record 5 of Set 13 | vicuna
# Processing Record 6 of Set 13 | nantucket
# Processing Record 7 of Set 13 | kutno
# Processing Record 8 of Set 13 | pouebo
# Processing Record 9 of Set 13 | mikhaylovka
# Processing Record 10 of Set 13 | zeya
# Processing Record 11 of Set 13 | burica
# City not found. Skipping...
# Processing Record 12 of Set 13 | milkovo
# Processing Record 13 of Set 13 | saint-pierre
# Processing Record 14 of Set 13 | seoul
# Processing Record 15 of Set 13 | yulara
# Processing Record 16 of Set 13 | basco
# Processing Record 17 of Set 13 | riberalta
# Processing Record 18 of Set 13 | raton
# Processing Record 19 of Set 13 | ormara
# Processing Record 20 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 13 | ouesso
# Processing Record 22 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 13 | sisimiut
# Processing Record 24 of Set 13 | xining
# Processing Record 25 of Set 13 | lhokseumawe
# Processing Record 26 of Set 13 | manzhouli
# Processing Record 27 of Set 13 | kaduna
# Processing Record 28 of Set 13 | surt
# Processing Record 29 of Set 13 | pangnirtung
# Processing Record 30 of Set 13 | la candelaria
# Processing Record 31 of Set 13 | fort nelson
# Processing Record 32 of Set 13 | tavai
# City not found. Skipping...
# Processing Record 33 of Set 13 | mlonggo
# Processing Record 34 of Set 13 | bosaso
# Processing Record 35 of Set 13 | miri
# Processing Record 36 of Set 13 | whitehorse
# Processing Record 37 of Set 13 | ewa beach
# Processing Record 38 of Set 13 | slave lake
# Processing Record 39 of Set 13 | yairipok
# Processing Record 40 of Set 13 | ulaangom
# Processing Record 41 of Set 13 | geraldton
# Processing Record 42 of Set 13 | sao pedro do sul
# Processing Record 43 of Set 13 | champerico
# Processing Record 44 of Set 13 | derzhavinsk
# Processing Record 45 of Set 13 | mnogovershinnyy
# Processing Record 46 of Set 13 | tungor
# Processing Record 47 of Set 13 | kyra
# Processing Record 48 of Set 13 | pekan
# Processing Record 49 of Set 13 | wanning
# Processing Record 50 of Set 13 | nakhon thai
# Processing Record 1 of Set 14 | baghdad
# Processing Record 2 of Set 14 | husavik
# Processing Record 3 of Set 14 | kajaani
# Processing Record 4 of Set 14 | jazzin
# City not found. Skipping...
# Processing Record 5 of Set 14 | tafresh
# Processing Record 6 of Set 14 | hami
# Processing Record 7 of Set 14 | sobolevo
# Processing Record 8 of Set 14 | isla mujeres
# Processing Record 9 of Set 14 | jiayuguan
# Processing Record 10 of Set 14 | kropotkin
# Processing Record 11 of Set 14 | mamakan
# Processing Record 12 of Set 14 | kolomak
# Processing Record 13 of Set 14 | portland
# Processing Record 14 of Set 14 | kokoshkino
# Processing Record 15 of Set 14 | shenjiamen
# Processing Record 16 of Set 14 | dudinka
# Processing Record 17 of Set 14 | churapcha
# Processing Record 18 of Set 14 | reyes
# Processing Record 19 of Set 14 | naze
# Processing Record 20 of Set 14 | muros
# Processing Record 21 of Set 14 | tarkwa
# Processing Record 22 of Set 14 | ohara
# Processing Record 23 of Set 14 | andreapol
# Processing Record 24 of Set 14 | road town
# Processing Record 25 of Set 14 | kruisfontein
# Processing Record 26 of Set 14 | jurm
# Processing Record 27 of Set 14 | springdale
# Processing Record 28 of Set 14 | eyl
# Processing Record 29 of Set 14 | yumen
# Processing Record 30 of Set 14 | lerwick
# Processing Record 31 of Set 14 | feuchtwangen
# Processing Record 32 of Set 14 | bac lieu
# Processing Record 33 of Set 14 | shihezi
# Processing Record 34 of Set 14 | hirara
# Processing Record 35 of Set 14 | alcaniz
# Processing Record 36 of Set 14 | taikang
# Processing Record 37 of Set 14 | alyangula
# Processing Record 38 of Set 14 | trelew
# Processing Record 39 of Set 14 | erzin
# Processing Record 40 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 14 | ust-karsk
# Processing Record 42 of Set 14 | kez
# Processing Record 43 of Set 14 | tateyama
# Processing Record 44 of Set 14 | mogadishu
# Processing Record 45 of Set 14 | dolores
# Processing Record 46 of Set 14 | okha
# Processing Record 47 of Set 14 | ndele
# Processing Record 48 of Set 14 | divnogorsk
# Processing Record 49 of Set 14 | ranau
# Processing Record 50 of Set 14 | araxa
# Processing Record 1 of Set 15 | san rafael del sur
# Processing Record 2 of Set 15 | olinda
# Processing Record 3 of Set 15 | pandan
# Processing Record 4 of Set 15 | kita
# Processing Record 5 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 6 of Set 15 | bra
# Processing Record 7 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 15 | paracatu
# Processing Record 9 of Set 15 | yako
# Processing Record 10 of Set 15 | sondrio
# Processing Record 11 of Set 15 | werda
# Processing Record 12 of Set 15 | rio cuarto
# Processing Record 13 of Set 15 | teya
# Processing Record 14 of Set 15 | calamar
# Processing Record 15 of Set 15 | mehran
# Processing Record 16 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 17 of Set 15 | presidencia roque saenz pena
# Processing Record 18 of Set 15 | bubaque
# Processing Record 19 of Set 15 | ponferrada
# Processing Record 20 of Set 15 | ganganagar
# Processing Record 21 of Set 15 | takoradi
# Processing Record 22 of Set 15 | fougamou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 660

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town -33.9258   18.4232     65.12        75           0
# 1       Ushuaia -54.8000  -68.3000     46.02        70          75
# 2          Hilo  19.7297 -155.0900     79.25        77          45
# 3      Ust-Nera  64.5667  143.2000    -16.33        98          69
# 4         Ancud -41.8697  -73.8203     57.85        80           7
# 5        Hobart -42.8794  147.3294     55.26        91          75
# 6         Kapaa  22.0752 -159.3190     80.19        71          20
# 7        Kodiak  57.7900 -152.4072     36.61        89          98
# 8  Constitucion -35.3333  -72.4167     66.61        59           7
# 9   Tuktoyaktuk  69.4541 -133.0374    -20.20        69           0
#
#    Wind Speed Country      Current Description                 Date
# 0       19.57      ZA                clear sky  2022-04-01 19:55:00
# 1       26.46      AR  light intensity drizzle  2022-04-01 19:56:28
# 2        5.01      US         scattered clouds  2022-04-01 19:57:34
# 3        1.45      RU            broken clouds  2022-04-01 19:57:34
# 4        8.05      CL                clear sky  2022-04-01 19:57:34
# 5        9.22      AU            broken clouds  2022-04-01 19:57:34
# 6        8.99      US               few clouds  2022-04-01 19:56:19
# 7       19.17      US          overcast clouds  2022-04-01 19:57:35
# 8       17.00      CL                clear sky  2022-04-01 19:57:35
# 9        6.91      CA                clear sky  2022-04-01 19:56:08

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town      ZA -33.9258   18.4232     65.12        75           0
# 1       Ushuaia      AR -54.8000  -68.3000     46.02        70          75
# 2          Hilo      US  19.7297 -155.0900     79.25        77          45
# 3      Ust-Nera      RU  64.5667  143.2000    -16.33        98          69
# 4         Ancud      CL -41.8697  -73.8203     57.85        80           7
# 5        Hobart      AU -42.8794  147.3294     55.26        91          75
# 6         Kapaa      US  22.0752 -159.3190     80.19        71          20
# 7        Kodiak      US  57.7900 -152.4072     36.61        89          98
# 8  Constitucion      CL -35.3333  -72.4167     66.61        59           7
# 9   Tuktoyaktuk      CA  69.4541 -133.0374    -20.20        69           0
#
#    Wind Speed      Current Description
# 0       19.57                clear sky
# 1       26.46  light intensity drizzle
# 2        5.01         scattered clouds
# 3        1.45            broken clouds
# 4        8.05                clear sky
# 5        9.22            broken clouds
# 6        8.99               few clouds
# 7       19.17          overcast clouds
# 8       17.00                clear sky
# 9        6.91                clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
